# %%
import pandas as pd

# %%
A=pd.read_csv('A.csv')
C=pd.read_csv('C.csv')
D=pd.read_csv('D.csv')

# %%
t=pd.read_csv('triples.csv')

# %%
t=t.reset_index(drop=True)

# %%
B=t['triple_B']

# %%
t=t.drop(columns=['triple_A','triple_B','triple_C','triple_D'])

# %%
t=pd.concat([t,A,B,C,D],axis=1)

# %%
pos=pd.read_csv('pos_sent.csv')
bu=pos[['topic','paper_idx','idx']]

# %%
t=pd.concat([t,bu],axis=1)
t
# Out:
#                 labels                                               text  \
# 0     research-problem                  Recurrent Neural Network Grammars
# 1                model  In this paper , we introduce recurrent neural ...
# 2                model  We give two variants of the algorithm , one fo...
# 3                model  Similar to previously published discriminative...
# 4                model  We present a simple importance sampling algori...
# ...                ...                                                ...
# 3144          approach  The key insights in our approach are 1 . to jo...
# 3145          approach  We refer to our model as BERT joint to emphasi...
# 3146   hyperparameters  We initialized our model from a BERT model alr...
# 3147   hyperparameters  We trained the model by minimizing loss L from...
# 3148           results  Our BERT model for NQ performs dramatically be...
#
#                                              predicates  \
# 0                                                    []
# 1     [('introduce', (5, 6)), ('of', (21, 22)), ('ex...
# 2     [('give', (1, 2)), ('of', (4, 5)), ('one for',...
# 3            [('with', (13, 14)), ('yields', (16, 17))]
# 4     [('present', (1, 2)), ('which uses', (7, 9)), ...
# ...                                                 ...
# 3144  [('in', (16, 17)), ('into', (33, 34)), ('by us...
# 3145  [('as', (5, 6)), ('in', (20, 21)), ('rather th...
# 3146  [('initialized', (1, 2)), ('from', (4, 5)), ('...
# 3147  [('trained', (1, 2)), ('by', (4, 5)), ('with',...
# 3148  [('for', (3, 4)), ('performs', (5, 6)), ('than...
#
#                                                subj/obj  \
# 0                                                    []
# 1     [('recurrent neural network grammars ( RNNGs',...
# 2     [('two variants', (2, 4)), ('algorithm', (6, 7...
# 3     [('greedy prediction', (11, 13)), ('our', (14,...
# 4     [('simple importance sampling algorithm', (3, ...
# ...                                                 ...
# 3144  [('short and long answers', (12, 16)), ('singl...
# 3145  [('BERT joint', (6, 8)), ('single model', (22,...
# 3146  [('our model', (2, 4)), ('BERT model', (6, 8))...
# 3147  [('model', (3, 4)), ('minimizing', (5, 6)), ('...
# 3148  [('Our BERT model', (0, 3)), ('NQ', (4, 5)), (...
#
#                                                triple_A triple_B  \
# 0                                                    []       []
# 1     [['sentences', 'explicitly models', 'nested , ...       []
# 2     [['two variants', 'of', 'algorithm'], ['two va...       []
# 3                [['greedy prediction', 'with', 'our']]       []
# 4     [['simple importance sampling algorithm', 'whi...       []
# ...                                                 ...      ...
# 3144  [['short and long answers', 'in', 'single mode...       []
# 3145                                                 []       []
# 3146  [['our model', 'from', 'BERT model'], ['our mo...       []
# 3147  [['model', 'by', 'minimizing'], ['loss L', 'wi...       []
# 3148  [['Our BERT model', 'for', 'NQ'], ['Our BERT m...       []
#
#                                                triple_C  \
# 0                                                    []
# 1     [['Model', 'introduce', 'recurrent neural netw...
# 2                   [['Model', 'give', 'two variants']]
# 3                                                    []
# 4     [['Model', 'present', 'simple importance sampl...
# ...                                                 ...
# 3144                                                 []
# 3145                 [['Approach', 'as', 'BERT joint']]
# 3146  [['Hyperparameters', 'initialized', 'our model']]
# 3147          [['Hyperparameters', 'trained', 'model']]
# 3148                                                 []
#
#                                      triple_D                       topic  \
# 0                                          []        constituency_parsing
# 1                                          []        constituency_parsing
# 2                                          []        constituency_parsing
# 3     [['Model', 'has', 'greedy prediction']]        constituency_parsing
# 4                                          []        constituency_parsing
# ...                                       ...                         ...
# 3144                                       []  natural_language_inference
# 3145                                       []  natural_language_inference
# 3146                                       []  natural_language_inference
# 3147                                       []  natural_language_inference
# 3148   [['Results', 'has', 'Our BERT model']]  natural_language_inference
#
#       paper_idx  idx
# 0             0    2
# 1             0   12
# 2             0   15
# 3             0   20
# 4             0   25
# ...         ...  ...
# 3144          9   17
# 3145          9   18
# 3146          9   54
# 3147          9   56
# 3148          9   60
#
# [3149 rows x 11 columns]

# %%
t.to_csv('try1.csv')
